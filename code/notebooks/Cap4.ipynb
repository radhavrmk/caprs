# %%
# !pip install scikit-surprise
# !conda install -c conda-forge scikit-surprise

# %%
import pandas as pd
import re
import numpy as np
import random
from scipy.stats import uniform as sp_rand
from scipy.stats import randint



pd.set_option('display.max_columns', 300)
pd.set_option('display.max_rows', 200)

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set(palette="magma_r")

# %%
from surprise import Reader
from surprise import SVD, SVDpp
from surprise import KNNBasic, KNNBaseline, KNNWithZScore, KNNWithMeans
from surprise import accuracy
from surprise import Dataset
from surprise.model_selection import train_test_split
from surprise.model_selection import cross_validate, GridSearchCV, RandomizedSearchCV

# %%
my_seed = 55
random.seed(my_seed)
np.random.seed(my_seed)

# %%
df_users = pd.read_csv("../..//data/processed/users.csv")
df_items = pd.read_csv("../..//data/processed/items.csv")
df_items.item_name_lower = df_items.item_name_lower.map(lambda x : x[:25])
df_items.columns
# Out:
# Index(['user_id', 'brand_id', 'store_id', 'product_id', 'item_name_lower',
#        'product_category_id', 'paid_price', 'size', 'on_sale', 'part_of_order',
#        'top_brand', 'color', 'Category Name', 'price_bin'],
#       dtype='object')

# %%
## Unique products
products =df_items.copy()
products.columns
products.drop(["user_id","store_id","paid_price","part_of_order","top_brand","color", "Category Name"],axis=1, inplace=True)
products.drop_duplicates(subset="product_id", inplace=True)
products.head()
# Out:
#   brand_id product_id            item_name_lower product_category_id size  \
# 0     loft   62733a41  petite textured pencil pa         123 - Pants  NaN
# 1     loft   7ca9f965   blurred fairisle sweater         114 - Knits  NaN
# 2     loft   6273435d   lou grey eyelash sweater         114 - Knits  NaN
# 3     loft   62732b46  petite plaid pencil pants         123 - Pants  NaN
# 4     loft   627342fa  petite custom stretch tro         123 - Pants  NaN
#
#    on_sale  price_bin
# 0    False          3
# 1    False          3
# 2    False          3
# 3    False          3
# 4    False          3

# %%
"""
This function creates a sparse matrix and a simple group by for user - product combinations
When store_cat is set to True, it uses product category and store as proxy for product 
Note : change this to create sparse matrices instead of returning pandas dataframes
"""
def get_user_prod_matrix(df, store_cat = True):
    df_items["store_cat"] = df_items.apply(lambda x : x["store_id"] + " - "+ str(x["product_category_id"]), axis=1)
    
    if store_cat:
        sparse = pd.pivot_table(df_items, index="user_id", columns="store_cat", values="product_id", aggfunc="count")
    else:
        sparse = pd.crosstab(index = df_items["user_id"], columns = df_items["product_id"], values="product_id", aggfunc="count")
    
    grp = sparse.stack().dropna().reset_index()       
    grp = grp.rename(columns={0:"rating"} )

    if store_cat:
        grp = grp.rename(columns = {"store_cat": "product_id"})


    return (grp, sparse)

# %%
x, y = get_user_prod_matrix(df_items)
print(x.head())
x2, y2 = get_user_prod_matrix(df_items, False)
print(x2.head())
unique_user_sample = x2.user_id.sample(5).values.tolist()
print(unique_user_sample)
# Out:
#          user_id                    product_id  rating
# 0  1485369350003   dsw - 210 - Boots & Booties     2.0
# 1  1485369350003              hm - 124 - Jeans     1.0
# 2  1485369350003  jcrewfactory - 111 - Blouses     1.0
# 3  1485369350003    jcrewfactory - 114 - Knits     1.0
# 4  1485369350003          loft - 111 - Blouses     5.0
#          user_id product_id  rating
# 0  1485369350003   00799605     1.0
# 1  1485369350003   01c00a9f     1.0
# 2  1485369350003   1389d2dd     1.0
# 3  1485369350003   1ff87a10     1.0
# 4  1485369350003   23583555     1.0
# [1534200663687, 1540229647916, 1530899668174, 1495117820151, 1506291233259]

# %%
def get_user_products(uid, df, n_count=10):
    cols_tokeep = ["product_id", "brand_id", "product_category_id", "rating","price_bin", "item_name_lower"]   
    col_names = ["Product ID", "Brand", "Category", "Times Bought","Price Bin", "Descr"]   


    user_products = df[df.user_id==uid]
    count = min(user_products.shape[0], n_count)
    user_top_products = user_products.sort_values("rating",ascending=False).head(count).merge(products, on="product_id")[cols_tokeep] 
    user_top_products.columns = col_names
    return user_top_products

# %%
def get_user_storecats(uid, df, n_count=10):
    cols_tokeep = ["product_id", "rating"]   
    col_names = ["Store - Category", "Times Bought"]   


    user_products = df[df.user_id==uid]
    count = min(user_products.shape[0], n_count)
    user_top_products = user_products.sort_values("rating",ascending=False).head(count)[cols_tokeep]
    user_top_products.columns = col_names
    return user_top_products

# %%
def get_n_recommendations(user_id, scores, n_recommendations=10):
    scores = scores[scores.uid == user_id]
    count = min(scores.shape[0], n_recommendations)
    cols_tokeep = ["est", "product_id", "brand_id", "product_category_id", "price_bin", "item_name_lower" ]
    col_names = ["Rating Estimate", "Product ID", "Brand", "Category", "Price Bin", "Descr"]
    temp_df = scores.sort_values("est", ascending=False).head(count).rename(columns={"iid":"product_id"}).merge(products, on="product_id")[cols_tokeep]
    temp_df.columns = col_names
    return temp_df

# %%
def get_n_recommendations_cat(user_id, scores, n_recommendations=10):
    scores = scores[scores.uid == user_id]
    count = min(scores.shape[0], n_recommendations)
    cols_tokeep = ["est", "iid"]
    col_names = ["Rating Estimate", "Store - Category"]
    temp_df = scores.sort_values("est", ascending=False).head(count)[cols_tokeep]
    temp_df.columns = col_names
    return temp_df

# %%
reader = Reader()

# %%
x2, y2 = get_user_prod_matrix(df_items, False)
reader2 = Reader()
data = Dataset.load_from_df(x2,reader)


param_grid = {'n_epochs': [5, 10], 'lr_all': [1e-4, 0.001, 0.002, 0.005],
              'reg_all': [0.4, 0.6],
              'random_state':[35]
            }
gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=3, refit=True, n_jobs=-1)
gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])
print(gs.best_score['mae'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
print(gs.best_params['mae'])

scoring_set = data.build_full_trainset().build_anti_testset()
scores = pd.DataFrame(gs.test(scoring_set))
# Out:
# 0.14449769341444396
# 0.03539348597953063
# {'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.6, 'random_state': 35}
# {'n_epochs': 5, 'lr_all': 0.002, 'reg_all': 0.4, 'random_state': 35}

# %%
for i in unique_user_sample:
    
    print("\n\n")
    print("*" * 60)
    
    print(f"\nUser {i} known purchases:")
    print("\n====================")
    print(get_user_products(i, x2,10))
    
    
    print(f"\nTop Recommendations for the user {i}:")
    print("\n================================:")
    print(get_n_recommendations(i,scores,7))
# Out:
# ************************************************************
#
# User 1534200663687 known purchases:
#
# ====================
#   Product ID        Brand          Category  Times Bought  Price Bin  \
# 0   00196351         None      122 - Shorts           1.0          1
# 1   34866379  fashionnova       124 - Jeans           1.0          2
# 2   341c1839    fabletics  160 - Activewear           1.0          2
# 3   341f5189         None   171 - Swimsuits           1.0          3
# 4   34310bc6   francescas        132 - Long           1.0          2
# 5   3440c403    forever21     153 - Blazers           1.0          2
# 6   3456eb6f  fashionnova     111 - Blouses           1.0          1
# 7   3460c83d    fabletics  160 - Activewear           1.0          1
# 8   34625c80      express       123 - Pants           1.0          2
# 9   34f514ae    forever21       113 - Tanks           1.0          1
#
#                        Descr
# 0  calvin klein high waisted
# 1               canopy jeans
# 2           marissa tank top
# 3      tommy hilfiger bikini
# 4            gio lace romper
# 5      doublebreasted blazer
# 6            elaina bodysuit
# 7         amber seamless bra
# 8  high waisted stripe ruffl
# 9        scoop neck tank top
#
# Top Recommendations for the user 1534200663687:
#
# ================================:
#    Rating Estimate Product ID            Brand               Category  \
# 0         1.150956   6279138a          oldnavy            113 - Tanks
# 1         1.103768   f30ce9ad  urbanoutfitters            240 - Heels
# 2         1.103604   2acab180             None          230 - Sandals
# 3         1.103444   2a56dfc6            lulus          230 - Sandals
# 4         1.102560   2ababc07             None          153 - Blazers
# 5         1.101908   2ab35afb             None  210 - Boots & Booties
# 6         1.101894   34239973             None           122 - Shorts
#
#    Price Bin                      Descr
# 0          1  relaxed racerback tank fo
# 1          1              rosebud salve
# 2          4  sam edelman yardley laceu
# 3          1  zoila natural ankle strap
# 4          3  tahari asl plus size oneb
# 5          3  vince camuto fileana spli
# 6          3  lauren ralph lauren plus
#
#
#
# ************************************************************
#
# User 1540229647916 known purchases:
#
# ====================
#   Product ID      Brand         Category  Times Bought  Price Bin  \
# 0   02322146  forever21   112 - T Shirts           1.0          1
# 1   05683759      lulus     141 - Casual           1.0          3
# 2   99745485      lulus     121 - Skirts           1.0          3
# 3   8cd13cdc      zaful  171 - Swimsuits           1.0          1
# 4   86323198      zaful     122 - Shorts           1.0          2
# 5   85116910      yandy  171 - Swimsuits           1.0          1
# 6   84576503  forever21     141 - Casual           1.0          2
# 7   82414766      lulus     141 - Casual           1.0          1
# 8   81928550  forever21      131 - Short           1.0          2
# 9   81748154      lulus     141 - Casual           1.0          1
#
#                        Descr
# 0        twisted cropped tee
# 1  queen of the city red str
# 2  suspend time grey and whi
# 3    one shoulder bikini set
# 4  ruffle striped shorts two
# 5  classic string bikini top
# 6   leopard print mini dress
# 7  do re mi blush pink lace
# 8      cutout harem jumpsuit
# 9  essence of style teal gre
#
# Top Recommendations for the user 1540229647916:
#
# ================================:
#    Rating Estimate Product ID             Brand       Category  Price Bin  \
# 0         1.187260   6279138a           oldnavy    113 - Tanks          1
# 1         1.185352   2a009ef7              None    123 - Pants          2
# 2         1.178496   2acab180              None  230 - Sandals          4
# 3         1.172291   2af2af55              loft    124 - Jeans          3
# 4         1.163041   55cbffde  abercrombiefitch    114 - Knits          1
# 5         1.141184   09715529           oldnavy    114 - Knits          2
# 6         1.135197   77319554       fashionnova    240 - Heels          2
#
#                        Descr
# 0  relaxed racerback tank fo
# 1  wit wisdom absolution str
# 2  sam edelman yardley laceu
# 3  petite curvy skinny jeans
# 4   slim ribbed crew sweater
# 5  cozy crewneck sweater for
# 6                  dana pump
#
#
#
# ************************************************************
#
# User 1530899668174 known purchases:
#
# ====================
#   Product ID        Brand          Category  Times Bought  Price Bin  \
# 0   2a70f7fd         None       124 - Jeans           2.0          4
# 1   2a0a9a83         None     111 - Blouses           2.0          1
# 2   2aa1ddee         None       240 - Heels           2.0          4
# 3   99843576   clubmonaco       114 - Knits           2.0          3
# 4   68337667        jcrew       151 - Coats           2.0          4
# 5   672143fe    cinqasept      141 - Casual           1.0          5
# 6   85707152    lululemon  160 - Activewear           1.0          4
# 7   780c8215    lululemon  160 - Activewear           1.0          2
# 8   74023387  giginewyork    310 - Clutches           1.0          4
# 9   71384554    anntaylor     230 - Sandals           1.0          4
#
#                        Descr
# 0         ogn cigarette jean
# 1   boyfriend chambray shirt
# 2         air talia wedge 40
# 3      tommie merino sweater
# 4  doublecloth colletta coat
# 5    nile lace bodycon dress
# 6             contour jacket
# 7     swiftly tech racerback
# 8                uber clutch
# 9  leannette suede leather b
#
# Top Recommendations for the user 1530899668174:
#
# ================================:
#    Rating Estimate Product ID    Brand               Category  Price Bin  \
# 0         1.211046   6279138a  oldnavy            113 - Tanks          1
# 1         1.159692   2ababc07     None          153 - Blazers          3
# 2         1.159565   2a56dfc6    lulus          230 - Sandals          1
# 3         1.156417   2a009ef7     None            123 - Pants          2
# 4         1.156082   2acab180     None          230 - Sandals          4
# 5         1.155973   2aa5da5d     None         250 - Sneakers          2
# 6         1.151027   2ab35afb     None  210 - Boots & Booties          3
#
#                        Descr
# 0  relaxed racerback tank fo
# 1  tahari asl plus size oneb
# 2  zoila natural ankle strap
# 3  wit wisdom absolution str
# 4  sam edelman yardley laceu
# 5  steve madden lancer sneak
# 6  vince camuto fileana spli
#
#
#
# ************************************************************
#
# User 1495117820151 known purchases:
#
# ====================
#   Product ID          Brand        Category  Times Bought  Price Bin  \
# 0   d002d8e4           None   230 - Sandals           2.0          2
# 1   f5ab83a7           None   163 - Bottoms           2.0          2
# 2   00366da3  anthropologie     123 - Pants           1.0          2
# 3   85d78599           loft     114 - Knits           1.0          3
# 4   8d72d708           loft    121 - Skirts           1.0          3
# 5   8c5830a3           None  250 - Sneakers           1.0          3
# 6   8b5c5c61      katespade   410 - Jewelry           1.0          1
# 7   8afc260e  anthropologie  112 - T Shirts           1.0          2
# 8   899110a3           None   163 - Bottoms           1.0          2
# 9   8990912a      baublebar   410 - Jewelry           1.0          2
#
#                        Descr
# 0  birkenstock gizeh flat sa
# 1          bp. moto leggings
# 2    sateen charlie trousers
# 3      ribbed peplum sweater
# 4  hydrangea pocket shift sk
# 5  tretorn women's camden 5
# 6       lady marmalade studs
# 7  ladder trim beach tee l r
# 8    hue moto denim leggings
# 9        bold beaded strands
#
# Top Recommendations for the user 1495117820151:
#
# ================================:
#    Rating Estimate Product ID            Brand               Category  \
# 0         1.159069   6279138a          oldnavy            113 - Tanks
# 1         1.111261   2a56dfc6            lulus          230 - Sandals
# 2         1.110542   f30ce9ad  urbanoutfitters            240 - Heels
# 3         1.110404   2ababc07             None          153 - Blazers
# 4         1.110009   2acab180             None          230 - Sandals
# 5         1.109716   34239973             None           122 - Shorts
# 6         1.109647   2ab35afb             None  210 - Boots & Booties
#
#    Price Bin                      Descr
# 0          1  relaxed racerback tank fo
# 1          1  zoila natural ankle strap
# 2          1              rosebud salve
# 3          3  tahari asl plus size oneb
# 4          4  sam edelman yardley laceu
# 5          3  lauren ralph lauren plus
# 6          3  vince camuto fileana spli
#
#
#
# ************************************************************
#
# User 1506291233259 known purchases:
#
# ====================
#   Product ID           Brand               Category  Times Bought  Price Bin  \
# 0   5162d48b            None           141 - Casual           2.0          5
# 1   021ec154       cinqasept           141 - Casual           2.0          4
# 2   4cf7e51a            asos          430 - Scarves           2.0          1
# 3   75e58132            None           141 - Casual           2.0          4
# 4   1ddcfb68            asos         250 - Sneakers           2.0          3
# 5   861f3933       blackhalo           141 - Casual           2.0          5
# 6   8a4aa983            tibi           141 - Casual           1.0          1
# 7   83424572  stuartweitzman  210 - Boots & Booties           1.0          6
# 8   84314555            None           122 - Shorts           1.0          3
# 9   84abbd66            None         112 - T Shirts           1.0          3
#
#                        Descr
# 0  cinq a sept nathalia dres
# 1        zahara ruffle dress
# 2  asos oversized scarf in b
# 3  theory apalia tweed dress
# 4  adidas originals supersta
# 5  jeera ruffle hem midi dre
# 6   black striped maxi dress
# 7  alllegs ultrastretch sued
# 8  joe's jeanshigh low short
# 9    vince dolman sleeve tee
#
# Top Recommendations for the user 1506291233259:
#
# ================================:
#    Rating Estimate Product ID            Brand       Category  Price Bin  \
# 0         1.167928   6279138a          oldnavy    113 - Tanks          1
# 1         1.118217   2a009ef7             None    123 - Pants          2
# 2         1.118078   2a56dfc6            lulus  230 - Sandals          1
# 3         1.117722   f30ce9ad  urbanoutfitters    240 - Heels          1
# 4         1.117082   2acab180             None  230 - Sandals          4
# 5         1.117070   34cbb0e2             None   122 - Shorts          3
# 6         1.116404   34239973             None   122 - Shorts          3
#
#                        Descr
# 0  relaxed racerback tank fo
# 1  wit wisdom absolution str
# 2  zoila natural ankle strap
# 3              rosebud salve
# 4  sam edelman yardley laceu
# 5  positively polished short
# 6  lauren ralph lauren plus

# %%
x2, y2 = get_user_prod_matrix(df_items)
reader2 = Reader()
data = Dataset.load_from_df(x2,reader)


param_grid = {'n_epochs': [5, 10], 'lr_all': [1e-4, 0.001, 0.002, 0.005],
              'reg_all': [0.4, 0.6],
              'random_state':[35]
             }
gs = GridSearchCV(SVDpp, param_grid, measures=['rmse', 'mae'], cv=3, refit=True,n_jobs=-1)
gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])
print(gs.best_score['mae'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
print(gs.best_params['mae'])

scoring_set = data.build_full_trainset().build_anti_testset()
scores = pd.DataFrame(gs.test(scoring_set))
# Out:
# 3.1956203709635425
# 1.6382187325434874
# {'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.4, 'random_state': 35}
# {'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.6, 'random_state': 35}

# %%
# unique_user_sample = x2.user_id.sample(5).values.tolist()
for i in unique_user_sample:
    
    print("\n\n")
    print("*" * 60)
    
    print(f"\nUser {i} known purchases:")
    print("\n====================")
    print(get_user_storecats(i, x2,10))
    
    
    print(f"\nTop Recommendations for the user {i}:")
    print("\n================================:")
    print(get_n_recommendations_cat(i,scores,7))
# Out:
# ************************************************************
#
# User 1534200663687 known purchases:
#
# ====================
#                   Store - Category  Times Bought
# 2033       zaful - 171 - Swimsuits          14.0
# 2011       poshmark - 122 - Shorts           7.0
# 1976  fabletics - 160 - Activewear           7.0
# 2005     missguided - 141 - Casual           5.0
# 2017      poshmark - 410 - Jewelry           4.0
# 1999    missguided - 111 - Blouses           4.0
# 1984      forever21 - 141 - Casual           4.0
# 1960           asos - 141 - Casual           4.0
# 1964            asos - 460 - Belts           4.0
# 1970         express - 114 - Knits           3.0
#
# Top Recommendations for the user 1534200663687:
#
# ================================:
#        Rating Estimate              Store - Category
# 56290         5.000000  lululemon - 160 - Activewear
# 56292         3.598057     nordstrom - 111 - Blouses
# 56557         3.563033            hm - 111 - Blouses
# 56310         3.482141      oldnavy - 112 - T Shirts
# 56222         3.273327          loft - 111 - Blouses
# 56245         3.271203    athleta - 160 - Activewear
# 56466         3.252766          lulus - 141 - Casual
#
#
#
# ************************************************************
#
# User 1540229647916 known purchases:
#
# ====================
#                 Store - Category  Times Bought
# 2606        lulus - 141 - Casual           9.0
# 2609     yandy - 171 - Swimsuits           3.0
# 2605        lulus - 121 - Skirts           2.0
# 2612     zaful - 171 - Swimsuits           2.0
# 2599  forever21 - 112 - T Shirts           1.0
# 2600    forever21 - 122 - Shorts           1.0
# 2601     forever21 - 131 - Short           1.0
# 2602    forever21 - 141 - Casual           1.0
# 2603  forever21 - 320 - Shoulder           1.0
# 2604         lulus - 114 - Knits           1.0
#
# Top Recommendations for the user 1540229647916:
#
# ================================:
#         Rating Estimate                  Store - Category
# 100619         3.913677     urbanoutfitters - 240 - Heels
# 99938          3.806865      fabletics - 160 - Activewear
# 99986          3.740029          oldnavy - 112 - T Shirts
# 100004         3.707171  urbanoutfitters - 112 - T Shirts
# 99968          3.537959         nordstrom - 111 - Blouses
# 99973          3.463850          nordstrom - 141 - Casual
# 99966          3.423371      lululemon - 160 - Activewear
#
#
#
# ************************************************************
#
# User 1530899668174 known purchases:
#
# ====================
#                      Store - Category  Times Bought
# 1524   saksfifthavenue - 141 - Casual           9.0
# 1504     lululemon - 160 - Activewear           7.0
# 1512          nordstrom - 240 - Heels           2.0
# 1491         clubmonaco - 114 - Knits           2.0
# 1500              jcrew - 151 - Coats           2.0
# 1499             jcrew - 141 - Casual           2.0
# 1502              jcrew - 220 - Flats           2.0
# 1521  saksfifthavenue - 111 - Blouses           2.0
# 1490          anntaylor - 240 - Heels           2.0
# 1489        anntaylor - 230 - Sandals           2.0
#
# Top Recommendations for the user 1530899668174:
#
# ================================:
#        Rating Estimate                  Store - Category
# 34572         4.535145      fabletics - 160 - Activewear
# 35235         3.389792     urbanoutfitters - 240 - Heels
# 34611         3.308531          oldnavy - 112 - T Shirts
# 34627         3.088415  urbanoutfitters - 112 - T Shirts
# 34766         3.081791              lulus - 141 - Casual
# 34530         3.051230              loft - 111 - Blouses
# 34860         3.020944                hm - 111 - Blouses
#
#
#
# ************************************************************
#
# User 1495117820151 known purchases:
#
# ====================
#                   Store - Category  Times Bought
# 204      katespade - 410 - Jewelry          24.0
# 161      baublebar - 410 - Jewelry          16.0
# 250       nordstrom - 141 - Casual          15.0
# 203     katespade - 320 - Shoulder          12.0
# 152   anthropologie - 141 - Casual          12.0
# 147  anthropologie - 111 - Blouses          11.0
# 247        nordstrom - 114 - Knits          10.0
# 215   lillypulitzer - 141 - Casual           9.0
# 245      nordstrom - 111 - Blouses           8.0
# 255      nordstrom - 163 - Bottoms           8.0
#
# Top Recommendations for the user 1495117820151:
#
# ================================:
#       Rating Estimate              Store - Category
# 2688         4.373082      oldnavy - 112 - T Shirts
# 3099         4.228012      forever21 - 141 - Casual
# 2846         4.223632            hm - 111 - Blouses
# 2749         4.061046          lulus - 141 - Casual
# 2661         3.945840  fabletics - 160 - Activewear
# 2690         3.943093         oldnavy - 114 - Knits
# 3091         3.882465     forever21 - 111 - Blouses
#
#
#
# ************************************************************
#
# User 1506291233259 known purchases:
#
# ====================
#                    Store - Category  Times Bought
# 638    bloomingdales - 141 - Casual          16.0
# 689  saksfifthavenue - 141 - Casual          11.0
# 653            jcrew - 141 - Casual          10.0
# 695         shopbop - 111 - Blouses           8.0
# 699          shopbop - 122 - Shorts           8.0
# 696        shopbop - 112 - T Shirts           7.0
# 701           shopbop - 124 - Jeans           7.0
# 708         shopbop - 410 - Jewelry           7.0
# 683          revolve - 141 - Casual           6.0
# 688   saksfifthavenue - 124 - Jeans           5.0
#
# Top Recommendations for the user 1506291233259:
#
# ================================:
#        Rating Estimate                  Store - Category
# 11881         5.000000      fabletics - 160 - Activewear
# 11906         5.000000      lululemon - 160 - Activewear
# 12489         4.305567     urbanoutfitters - 240 - Heels
# 11936         3.987460  urbanoutfitters - 112 - T Shirts
# 11918         3.911797          oldnavy - 112 - T Shirts
# 11840         3.783551              loft - 111 - Blouses
# 12356         3.666048          forever21 - 141 - Casual

# %%
x2, y2 = get_user_prod_matrix(df_items)
reader2 = Reader()
data = Dataset.load_from_df(x2,reader)


param_grid = {'n_epochs': [5, 10, 15], 'lr_all': np.linspace(1e-4,2e-1,200),
              'reg_all': np.linspace(0,1,100),
              'random_state':[35]
             }
gs = RandomizedSearchCV(SVDpp, param_grid, measures=['rmse', 'mae'], cv=3, refit=True,n_jobs=-1, n_iter=50)
gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])
print(gs.best_score['mae'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
print(gs.best_params['mae'])

scoring_set = data.build_full_trainset().build_anti_testset()
scores = pd.DataFrame(gs.test(scoring_set))
# Out:
# 3.973290305609814
# 2.87181722681501
# {'n_epochs': 15, 'lr_all': 0.031240201005025125, 'reg_all': 0.6767676767676768, 'random_state': 35}
# {'n_epochs': 5, 'lr_all': 0.026217587939698493, 'reg_all': 0.08080808080808081, 'random_state': 35}

# %%
# unique_user_sample = x2.user_id.sample(5).values.tolist()
for i in unique_user_sample:
    
    print("\n\n")
    print("*" * 60)
    
    print(f"\nUser {i} known purchases:")
    print("\n====================")
    print(get_user_storecats(i, x2,10))
    
    
    print(f"\nTop Recommendations for the user {i}:")
    print("\n================================:")
    print(get_n_recommendations_cat(i,scores,7))
# Out:
# ************************************************************
#
# User 1534200663687 known purchases:
#
# ====================
#                   Store - Category  Times Bought
# 2033       zaful - 171 - Swimsuits          14.0
# 2011       poshmark - 122 - Shorts           7.0
# 1976  fabletics - 160 - Activewear           7.0
# 2005     missguided - 141 - Casual           5.0
# 2017      poshmark - 410 - Jewelry           4.0
# 1999    missguided - 111 - Blouses           4.0
# 1984      forever21 - 141 - Casual           4.0
# 1960           asos - 141 - Casual           4.0
# 1964            asos - 460 - Belts           4.0
# 1970         express - 114 - Knits           3.0
#
# Top Recommendations for the user 1534200663687:
#
# ================================:
#        Rating Estimate                 Store - Category
# 56218                5      dsw - 210 - Boots & Booties
# 57072                5  bananarepublic - 112 - T Shirts
# 57090                5            jcrew - 152 - Jackets
# 57089                5      fabletics - 340 - Backpacks
# 57088                5        fabletics - 163 - Bottoms
# 57087                5        fabletics - 152 - Jackets
# 57086                5          fabletics - 151 - Coats
#
#
#
# ************************************************************
#
# User 1540229647916 known purchases:
#
# ====================
#                 Store - Category  Times Bought
# 2606        lulus - 141 - Casual           9.0
# 2609     yandy - 171 - Swimsuits           3.0
# 2605        lulus - 121 - Skirts           2.0
# 2612     zaful - 171 - Swimsuits           2.0
# 2599  forever21 - 112 - T Shirts           1.0
# 2600    forever21 - 122 - Shorts           1.0
# 2601     forever21 - 131 - Short           1.0
# 2602    forever21 - 141 - Casual           1.0
# 2603  forever21 - 320 - Shoulder           1.0
# 2604         lulus - 114 - Knits           1.0
#
# Top Recommendations for the user 1540229647916:
#
# ================================:
#         Rating Estimate             Store - Category
# 99891                 5  dsw - 210 - Boots & Booties
# 100802                5    stitchfix - 410 - Jewelry
# 100810                5          jcrew - 131 - Short
# 100809                5     freepeople - 114 - Knits
# 100808                5     clubmonaco - 114 - Knits
# 100807                5    anntaylor - 230 - Sandals
# 100806                5      anntaylor - 113 - Tanks
#
#
#
# ************************************************************
#
# User 1530899668174 known purchases:
#
# ====================
#                      Store - Category  Times Bought
# 1524   saksfifthavenue - 141 - Casual           9.0
# 1504     lululemon - 160 - Activewear           7.0
# 1512          nordstrom - 240 - Heels           2.0
# 1491         clubmonaco - 114 - Knits           2.0
# 1500              jcrew - 151 - Coats           2.0
# 1499             jcrew - 141 - Casual           2.0
# 1502              jcrew - 220 - Flats           2.0
# 1521  saksfifthavenue - 111 - Blouses           2.0
# 1490          anntaylor - 240 - Heels           2.0
# 1489        anntaylor - 230 - Sandals           2.0
#
# Top Recommendations for the user 1530899668174:
#
# ================================:
#        Rating Estimate               Store - Category
# 34526                5    dsw - 210 - Boots & Booties
# 35423                5         jcpenney - 114 - Knits
# 35421                5       jcpenney - 111 - Blouses
# 35420                5         zappos - 163 - Bottoms
# 35419                5  victoriassecret - 460 - Belts
# 35418                5      stitchfix - 410 - Jewelry
# 35417                5      stitchfix - 153 - Blazers
#
#
#
# ************************************************************
#
# User 1495117820151 known purchases:
#
# ====================
#                   Store - Category  Times Bought
# 204      katespade - 410 - Jewelry          24.0
# 161      baublebar - 410 - Jewelry          16.0
# 250       nordstrom - 141 - Casual          15.0
# 203     katespade - 320 - Shoulder          12.0
# 152   anthropologie - 141 - Casual          12.0
# 147  anthropologie - 111 - Blouses          11.0
# 247        nordstrom - 114 - Knits          10.0
# 215   lillypulitzer - 141 - Casual           9.0
# 245      nordstrom - 111 - Blouses           8.0
# 255      nordstrom - 163 - Bottoms           8.0
#
# Top Recommendations for the user 1495117820151:
#
# ================================:
#       Rating Estimate               Store - Category
# 2627                5               hm - 124 - Jeans
# 3459                5    therealreal - 111 - Blouses
# 3466                5          express - 124 - Jeans
# 3465                5         express - 121 - Skirts
# 3464                5        express - 111 - Blouses
# 3463                5  calvinklein - 171 - Swimsuits
# 3462                5  urbanoutfitters - 460 - Belts
#
#
#
# ************************************************************
#
# User 1506291233259 known purchases:
#
# ====================
#                    Store - Category  Times Bought
# 638    bloomingdales - 141 - Casual          16.0
# 689  saksfifthavenue - 141 - Casual          11.0
# 653            jcrew - 141 - Casual          10.0
# 695         shopbop - 111 - Blouses           8.0
# 699          shopbop - 122 - Shorts           8.0
# 696        shopbop - 112 - T Shirts           7.0
# 701           shopbop - 124 - Jeans           7.0
# 708         shopbop - 410 - Jewelry           7.0
# 683          revolve - 141 - Casual           6.0
# 688   saksfifthavenue - 124 - Jeans           5.0
#
# Top Recommendations for the user 1506291233259:
#
# ================================:
#        Rating Estimate                   Store - Category
# 11836                5        dsw - 210 - Boots & Booties
# 12690                5    saksfifthavenue - 230 - Sandals
# 12708                5           aeropostale - 161 - Tops
# 12707                5         aeropostale - 122 - Shorts
# 12706                5       aeropostale - 112 - T Shirts
# 12705                5             zulily - 230 - Sandals
# 12704                5  sierratradingpost - 230 - Sandals

# %%
x2, y2 = get_user_prod_matrix(df_items)
reader2 = Reader()
data = Dataset.load_from_df(x2,reader)

def trainSVD(data):
    param_grid = {'n_epochs': [5, 10, 15], 'lr_all': np.linspace(1e-4,2e-1,200),
              'reg_all': np.linspace(0,1,100),
              'random_state':[35]
             }
    
    gs = RandomizedSearchCV(SVDpp, param_grid, measures=['rmse', 'mae'], cv=3, refit=True,n_jobs=-1, n_iter=50)
    gs.fit(data)

    # best RMSE score
    print(gs.best_score['rmse'])
    print(gs.best_score['mae'])

    # combination of parameters that gave the best RMSE score
    print(gs.best_params['rmse'])
    print(gs.best_params['mae'])

    train_set = data.build_full_trainset()
    all_set = train_set.build_testset()
    anti_set = train_set.build_anti_testset()
    all_scores = pd.DataFrame(gs.test(all_set))
    anti_scores = pd.DataFrame(gs.test(anti_set))
    return (all_scores, anti_scores)

all_s, anti_s = trainSVD(data)
# Out:
# 3.2029747788343705
# 1.5996091107450336
# {'n_epochs': 15, 'lr_all': 0.011149748743718593, 'reg_all': 0.25252525252525254, 'random_state': 35}
# {'n_epochs': 10, 'lr_all': 0.014163316582914573, 'reg_all': 0.4444444444444445, 'random_state': 35}

# %%
# unique_user_sample = x2.user_id.sample(5).values.tolist()
for i in unique_user_sample:
    
    print("\n\n")
    print("*" * 60)
    
    print(f"\nUser {i} known purchases:")
    print("\n====================")
    print(get_user_storecats(i, x2,10))
    
    
    print(f"\nTop Recommendations for the user {i}:")
    print("\n================================:")
    print(get_n_recommendations_cat(i,anti_s,7))
# Out:
# ************************************************************
#
# User 1534200663687 known purchases:
#
# ====================
#                   Store - Category  Times Bought
# 2033       zaful - 171 - Swimsuits          14.0
# 2011       poshmark - 122 - Shorts           7.0
# 1976  fabletics - 160 - Activewear           7.0
# 2005     missguided - 141 - Casual           5.0
# 2017      poshmark - 410 - Jewelry           4.0
# 1999    missguided - 111 - Blouses           4.0
# 1984      forever21 - 141 - Casual           4.0
# 1960           asos - 141 - Casual           4.0
# 1964            asos - 460 - Belts           4.0
# 1970         express - 114 - Knits           3.0
#
# Top Recommendations for the user 1534200663687:
#
# ================================:
#        Rating Estimate                           Store - Category
# 56290         5.000000               lululemon - 160 - Activewear
# 56245         4.499094                 athleta - 160 - Activewear
# 56557         3.962084                         hm - 111 - Blouses
# 56238         3.932637               renttherunway - 141 - Casual
# 57016         3.252918  americaneagleoutfitters - 171 - Swimsuits
# 56558         3.071103                           hm - 114 - Knits
# 56714         3.048174             saksfifthavenue - 141 - Casual
#
#
#
# ************************************************************
#
# User 1540229647916 known purchases:
#
# ====================
#                 Store - Category  Times Bought
# 2606        lulus - 141 - Casual           9.0
# 2609     yandy - 171 - Swimsuits           3.0
# 2605        lulus - 121 - Skirts           2.0
# 2612     zaful - 171 - Swimsuits           2.0
# 2599  forever21 - 112 - T Shirts           1.0
# 2600    forever21 - 122 - Shorts           1.0
# 2601     forever21 - 131 - Short           1.0
# 2602    forever21 - 141 - Casual           1.0
# 2603  forever21 - 320 - Shoulder           1.0
# 2604         lulus - 114 - Knits           1.0
#
# Top Recommendations for the user 1540229647916:
#
# ================================:
#         Rating Estimate                  Store - Category
# 100004         5.000000  urbanoutfitters - 112 - T Shirts
# 99986          5.000000          oldnavy - 112 - T Shirts
# 100619         5.000000     urbanoutfitters - 240 - Heels
# 99911          4.102802      renttherunway - 141 - Casual
# 99897          3.900584                loft - 114 - Knits
# 99895          3.711973              loft - 111 - Blouses
# 99938          3.701059      fabletics - 160 - Activewear
#
#
#
# ************************************************************
#
# User 1530899668174 known purchases:
#
# ====================
#                      Store - Category  Times Bought
# 1524   saksfifthavenue - 141 - Casual           9.0
# 1504     lululemon - 160 - Activewear           7.0
# 1512          nordstrom - 240 - Heels           2.0
# 1491         clubmonaco - 114 - Knits           2.0
# 1500              jcrew - 151 - Coats           2.0
# 1499             jcrew - 141 - Casual           2.0
# 1502              jcrew - 220 - Flats           2.0
# 1521  saksfifthavenue - 111 - Blouses           2.0
# 1490          anntaylor - 240 - Heels           2.0
# 1489        anntaylor - 230 - Sandals           2.0
#
# Top Recommendations for the user 1530899668174:
#
# ================================:
#        Rating Estimate               Store - Category
# 34572         5.000000   fabletics - 160 - Activewear
# 34991         3.753030   bloomingdales - 141 - Casual
# 34546         3.292633   renttherunway - 141 - Casual
# 34860         3.224291             hm - 111 - Blouses
# 34530         3.112749           loft - 111 - Blouses
# 35235         3.090685  urbanoutfitters - 240 - Heels
# 34532         3.055911             loft - 114 - Knits
#
#
#
# ************************************************************
#
# User 1495117820151 known purchases:
#
# ====================
#                   Store - Category  Times Bought
# 204      katespade - 410 - Jewelry          24.0
# 161      baublebar - 410 - Jewelry          16.0
# 250       nordstrom - 141 - Casual          15.0
# 203     katespade - 320 - Shoulder          12.0
# 152   anthropologie - 141 - Casual          12.0
# 147  anthropologie - 111 - Blouses          11.0
# 247        nordstrom - 114 - Knits          10.0
# 215   lillypulitzer - 141 - Casual           9.0
# 245      nordstrom - 111 - Blouses           8.0
# 255      nordstrom - 163 - Bottoms           8.0
#
# Top Recommendations for the user 1495117820151:
#
# ================================:
#       Rating Estimate                         Store - Category
# 2691              5.0                   oldnavy - 141 - Casual
# 3094              5.0                  forever21 - 114 - Knits
# 3324              5.0  americaneagleoutfitters - 155 - Hoodies
# 2661              5.0             fabletics - 160 - Activewear
# 3224              5.0           urbanoutfitters - 141 - Casual
# 3516              5.0                 poshmark - 111 - Blouses
# 3187              5.0                freepeople - 141 - Casual
#
#
#
# ************************************************************
#
# User 1506291233259 known purchases:
#
# ====================
#                    Store - Category  Times Bought
# 638    bloomingdales - 141 - Casual          16.0
# 689  saksfifthavenue - 141 - Casual          11.0
# 653            jcrew - 141 - Casual          10.0
# 695         shopbop - 111 - Blouses           8.0
# 699          shopbop - 122 - Shorts           8.0
# 696        shopbop - 112 - T Shirts           7.0
# 701           shopbop - 124 - Jeans           7.0
# 708         shopbop - 410 - Jewelry           7.0
# 683          revolve - 141 - Casual           6.0
# 688   saksfifthavenue - 124 - Jeans           5.0
#
# Top Recommendations for the user 1506291233259:
#
# ================================:
#        Rating Estimate                  Store - Category
# 11863              5.0        athleta - 160 - Activewear
# 11840              5.0              loft - 111 - Blouses
# 11906              5.0      lululemon - 160 - Activewear
# 11919              5.0             oldnavy - 113 - Tanks
# 11936              5.0  urbanoutfitters - 112 - T Shirts
# 12003              5.0         katespade - 410 - Jewelry
# 11938              5.0     victoriassecret - 113 - Tanks

# %%
# unique_user_sample = x2.user_id.sample(5).values.tolist()
for i in unique_user_sample:
    
    print("\n\n")
    print("*" * 60)
    
    print(f"\nUser {i} known purchases:")
    print("\n====================")
    print(get_user_storecats(i, x2,10))
    
    
    print(f"\nTop Recommendations for the user {i}:")
    print("\n================================:")
    print(get_n_recommendations_cat(i,all_s,7))
# Out:
# ************************************************************
#
# User 1534200663687 known purchases:
#
# ====================
#                   Store - Category  Times Bought
# 2033       zaful - 171 - Swimsuits          14.0
# 2011       poshmark - 122 - Shorts           7.0
# 1976  fabletics - 160 - Activewear           7.0
# 2005     missguided - 141 - Casual           5.0
# 2017      poshmark - 410 - Jewelry           4.0
# 1999    missguided - 111 - Blouses           4.0
# 1984      forever21 - 141 - Casual           4.0
# 1960           asos - 141 - Casual           4.0
# 1964            asos - 460 - Belts           4.0
# 1970         express - 114 - Knits           3.0
#
# Top Recommendations for the user 1534200663687:
#
# ================================:
#       Rating Estimate              Store - Category
# 2033         5.000000       zaful - 171 - Swimsuits
# 1976         5.000000  fabletics - 160 - Activewear
# 1960         4.418134           asos - 141 - Casual
# 2011         3.677708       poshmark - 122 - Shorts
# 1984         3.114829      forever21 - 141 - Casual
# 1981         3.017989     forever21 - 111 - Blouses
# 2005         2.866382     missguided - 141 - Casual
#
#
#
# ************************************************************
#
# User 1540229647916 known purchases:
#
# ====================
#                 Store - Category  Times Bought
# 2606        lulus - 141 - Casual           9.0
# 2609     yandy - 171 - Swimsuits           3.0
# 2605        lulus - 121 - Skirts           2.0
# 2612     zaful - 171 - Swimsuits           2.0
# 2599  forever21 - 112 - T Shirts           1.0
# 2600    forever21 - 122 - Shorts           1.0
# 2601     forever21 - 131 - Short           1.0
# 2602    forever21 - 141 - Casual           1.0
# 2603  forever21 - 320 - Shoulder           1.0
# 2604         lulus - 114 - Knits           1.0
#
# Top Recommendations for the user 1540229647916:
#
# ================================:
#       Rating Estimate              Store - Category
# 2606         5.000000          lulus - 141 - Casual
# 2612         2.849120       zaful - 171 - Swimsuits
# 2608         2.734336  renttherunway - 144 - Formal
# 2605         2.051481          lulus - 121 - Skirts
# 2609         2.014352       yandy - 171 - Swimsuits
# 2610         1.696168          zaful - 121 - Skirts
# 2603         1.614962    forever21 - 320 - Shoulder
#
#
#
# ************************************************************
#
# User 1530899668174 known purchases:
#
# ====================
#                      Store - Category  Times Bought
# 1524   saksfifthavenue - 141 - Casual           9.0
# 1504     lululemon - 160 - Activewear           7.0
# 1512          nordstrom - 240 - Heels           2.0
# 1491         clubmonaco - 114 - Knits           2.0
# 1500              jcrew - 151 - Coats           2.0
# 1499             jcrew - 141 - Casual           2.0
# 1502              jcrew - 220 - Flats           2.0
# 1521  saksfifthavenue - 111 - Blouses           2.0
# 1490          anntaylor - 240 - Heels           2.0
# 1489        anntaylor - 230 - Sandals           2.0
#
# Top Recommendations for the user 1530899668174:
#
# ================================:
#       Rating Estimate                Store - Category
# 1504         5.000000    lululemon - 160 - Activewear
# 1524         3.916688  saksfifthavenue - 141 - Casual
# 1499         2.315758            jcrew - 141 - Casual
# 1511         2.071296         nordstrom - 124 - Jeans
# 1496         1.792405           jcrew - 111 - Blouses
# 1510         1.766683         nordstrom - 114 - Knits
# 1497         1.765956             jcrew - 114 - Knits
#
#
#
# ************************************************************
#
# User 1495117820151 known purchases:
#
# ====================
#                   Store - Category  Times Bought
# 204      katespade - 410 - Jewelry          24.0
# 161      baublebar - 410 - Jewelry          16.0
# 250       nordstrom - 141 - Casual          15.0
# 203     katespade - 320 - Shoulder          12.0
# 152   anthropologie - 141 - Casual          12.0
# 147  anthropologie - 111 - Blouses          11.0
# 247        nordstrom - 114 - Knits          10.0
# 215   lillypulitzer - 141 - Casual           9.0
# 245      nordstrom - 111 - Blouses           8.0
# 255      nordstrom - 163 - Bottoms           8.0
#
# Top Recommendations for the user 1495117820151:
#
# ================================:
#      Rating Estimate              Store - Category
# 209              5.0       lastcall - 141 - Casual
# 161              5.0     baublebar - 410 - Jewelry
# 215              5.0  lillypulitzer - 141 - Casual
# 204              5.0     katespade - 410 - Jewelry
# 203              5.0    katespade - 320 - Shoulder
# 245              5.0     nordstrom - 111 - Blouses
# 246              5.0    nordstrom - 112 - T Shirts
#
#
#
# ************************************************************
#
# User 1506291233259 known purchases:
#
# ====================
#                    Store - Category  Times Bought
# 638    bloomingdales - 141 - Casual          16.0
# 689  saksfifthavenue - 141 - Casual          11.0
# 653            jcrew - 141 - Casual          10.0
# 695         shopbop - 111 - Blouses           8.0
# 699          shopbop - 122 - Shorts           8.0
# 696        shopbop - 112 - T Shirts           7.0
# 701           shopbop - 124 - Jeans           7.0
# 708         shopbop - 410 - Jewelry           7.0
# 683          revolve - 141 - Casual           6.0
# 688   saksfifthavenue - 124 - Jeans           5.0
#
# Top Recommendations for the user 1506291233259:
#
# ================================:
#      Rating Estimate                Store - Category
# 708              5.0         shopbop - 410 - Jewelry
# 678              5.0    renttherunway - 141 - Casual
# 689              5.0  saksfifthavenue - 141 - Casual
# 695              5.0         shopbop - 111 - Blouses
# 653              5.0            jcrew - 141 - Casual
# 699              5.0          shopbop - 122 - Shorts
# 638              5.0    bloomingdales - 141 - Casual

# %%
x2, y2 = get_user_prod_matrix(df_items)
reader2 = Reader()
data = Dataset.load_from_df(x2,reader)


param_grid = {'n_epochs': [5, 10, 15], 'lr_all': np.linspace(1e-4,2e-1,200),
              'reg_all': np.linspace(0,1,100),
              'random_state':[35]
             }
gs = RandomizedSearchCV(SVDpp, param_grid, measures=['rmse', 'mae'], cv=3, refit=True,n_jobs=-1, n_iter=50)
gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])
print(gs.best_score['mae'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
print(gs.best_params['mae'])

scoring_set = data.build_full_trainset().build_anti_testset()
scores = pd.DataFrame(gs.test(scoring_set))

# %%
x2.head()
# Out:
#          user_id                    product_id  rating
# 0  1485369350003   dsw - 210 - Boots & Booties     2.0
# 1  1485369350003              hm - 124 - Jeans     1.0
# 2  1485369350003  jcrewfactory - 111 - Blouses     1.0
# 3  1485369350003    jcrewfactory - 114 - Knits     1.0
# 4  1485369350003          loft - 111 - Blouses     5.0

# %%
x2, y2 = get_user_prod_matrix(df_items)
reader2 = Reader()
data = Dataset.load_from_df(x2,reader)


# param_grid = {'n_epochs': [5, 10, 15], 'lr_all': np.linspace(1e-4,2e-1,200),
#               'reg_all': np.linspace(0,1,100),
#               'random_state':[35]
#              }

param_grid = {'k': [1,3,5,10,15,20,25,30,35,40,45,50],
              'sim_options': {'name': ['msd', 'cosine'],
                              'min_support': [1,3,5,10,15,20,25,30,35,40,45,50],
                              'user_based': [False, True]},
              }
gs = RandomizedSearchCV(KNNBasic, param_grid,  measures=['rmse', 'mae'], cv=3, refit=True,n_jobs=-1, n_iter=50)
gs.fit(data)

# best RMSE score
print(gs.best_score['rmse'])
print(gs.best_score['mae'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
print(gs.best_params['mae'])

scoring_set = data.build_full_trainset().build_anti_testset()
scores = pd.DataFrame(gs.test(scoring_set))
# Out:
# /anaconda3/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# /anaconda3/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# 3.2090959510215398
# 1.6580749748693095
# {'k': 25, 'sim_options': {'name': 'cosine', 'min_support': 3, 'user_based': False}}
# {'k': 20, 'sim_options': {'name': 'cosine', 'min_support': 5, 'user_based': False}}

# %%
scores.head()
# Out:
#              uid                               iid      r_ui       est  \
# 0  1485369350003  abercrombiefitch - 111 - Blouses  2.333227  2.333227
# 1  1485369350003      anthropologie - 141 - Casual  2.333227  4.814498
# 2  1485369350003              asos - 111 - Blouses  2.333227  2.047616
# 3  1485369350003              asos - 430 - Scarves  2.333227  2.333227
# 4  1485369350003        athleta - 160 - Activewear  2.333227  2.179130
#
#                                              details
# 0  {'was_impossible': True, 'reason': 'Not enough...
# 1           {'actual_k': 8, 'was_impossible': False}
# 2           {'actual_k': 2, 'was_impossible': False}
# 3  {'was_impossible': True, 'reason': 'Not enough...
# 4           {'actual_k': 2, 'was_impossible': False}
